# %%
pip install mistralai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 503.0/503.0 kB 11.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.3/160.3 kB 10.5 MB/s eta 0:00:00
# ...

# %%
import os
from mistralai import Mistral
os.environ['MISTRAL_API_KEY']="eB0pgT8RDaH721uIplb5q7aVUmrsVU1y"
apikey=os.environ['MISTRAL_API_KEY']
client=Mistral(apikey)
result=client.chat.complete(
    model="mistral-medium",
    messages=[{'role':'user','content':'who is vishwamohan'}],
    top_p=0.5,
    temperature=0.5,
    max_tokens=1000
)

print(result.choices[0].message.content)
# Out:
# Vishwamohan is a name that could refer to several individuals, but based on common references, here are a few possibilities:
#
# 1. **Vishwamohan Bhatt** – A renowned Indian slide guitarist and composer, known for his innovative fusion of Indian classical music with Western styles. He is the son of the famous sitarist Ravi Shankar and the brother of Anoushka Shankar. His most famous work is the Grammy-winning album *A Meeting by the River* (1994) with Ry Cooder.
#
# 2. **Vishwamohan Katti** – A former Director of the Indian Institute of Science (IISc), Bangalore, and a distinguished scientist in the field of structural engineering.
#
# 3. **Vishwamohan Sharma** – A name that could belong to various individuals in different fields, such as academics, politics, or arts.
#
# If you're referring to a specific person, could you provide more context (e.g., profession, field, or notable achievements)? I’d be happy to give a more precise answer!

# %%
def bnm(topic,no_of_q):
  prompt=f"""
  can you {no_of_q} generate question on the {topic} in format
  Q:
  A:
  """
  res=client.chat.complete(
    model="mistral-medium",
    messages=[{'role':'user','content':prompt}],
  )
  return res.choices[0].message.content
topic="H D Devegowda"
no_of_q=4
bnm(topic,no_of_q)
# Out:
# 'Here are four questions about **H. D. Deve Gowda** in the requested format:\n\n---\n\n**Q1:** Who was **H. D. Deve Gowda**, and which political party did he found?\n**A:** H. D. Deve Gowda was the **11th Prime Minister of India (1996–1997)** and a prominent leader from Karnataka. He founded the **Janata Dal (Secular) [JD(S)]** in 1999 after splitting from the Janata Dal.\n\n---\n\n**Q2:** Under what circumstances did Deve Gowda become the Prime Minister of India in 1996?\n**A:** Deve Gowda became PM in **June 1996** after the **United Front (UF) coalition**, supported by the **Congress Party**, chose him as a compromise candidate to lead the government following the **1996 general elections**, where no single party won a majority.\n\n---\n\n**Q3:** What major challenges did Deve Gowda’s government face during his brief tenure as PM?\n**A:** His government faced:\n- **Political instability** (reliance on Congress support, which withdrew in 1997).\n- **Economic pressures** (post-liber
# ...
